# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelNicola2H/UII-Act-3-P1-m-dicos-especialistas-en-cardiolog-a.-Samuel-Nicola-0106/blob/main/uii_act_3_menu_p1_de_opciones_samuel_nicola_0106.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Hugo Samuel Nicola  NC = 2530805128**0106**
# #### Fecha 12/Marzo/2026
# #### numero de lista = 40
# #### numero de problema = 40
# #### Redaccion del problema:Crear un programa que permita administrar una lista de médicos especialistas en cardiología.
# #### menu
# 1.  Agregar
# 2.  Modificar
# 3.  Borrar
# 4.  Ver listas
# 5.  Salir

# %%
Cardiologos = []

while True:
  print("1 Agregar elemento a la lista")
  print("2 Modificar elemento de la lista")
  print("3 Borrar elemento de la lista")
  print("4 Mostrar elementos de la lista ")
  print("5 Salir")

  Opcion = int(input("Inserte la opcion a realizar: "))

  if Opcion == 1:
    Nombre = input("Inserte el nombre del cardiólogo que desea agregar: ")
    Cardiologos.append(Nombre)

  elif Opcion == 2:
    Posicion = int(input("Inserte la posicion del cardiólogo que desea modificar: "))
    Nombre = input("Inserte el nuevo nombre del cardiólogo: ")
    Cardiologos[Posicion] = Nombre

  elif Opcion == 3:
    Posicion = int(input("Inserte la posicion del cardiólogo que desea borrar: "))
    Cardiologos.pop(Posicion)

  elif Opcion == 4:
    for X in Cardiologos:
      print(X)

  elif Opcion == 5:
    break

  else:
    print("Opcion no valida")

print("Programa realizado por Samuel Nicola NL = 40")
# Out:
# 1 Agregar elemento a la lista
# 2 Modificar elemento de la lista
# 3 Borrar elemento de la lista
# 4 Mostrar elementos de la lista
# 5 Salir
# Inserte la opcion a realizar: 1
# Inserte el nombre del cardiólogo que desea agregar: Juan
# 1 Agregar elemento a la lista
# 2 Modificar elemento de la lista
# 3 Borrar elemento de la lista
# 4 Mostrar elementos de la lista
# 5 Salir
# Inserte la opcion a realizar: 1
# Inserte el nombre del cardiólogo que desea agregar: Jose
# 1 Agregar elemento a la lista
# 2 Modificar elemento de la lista
# 3 Borrar elemento de la lista
# 4 Mostrar elementos de la lista
# 5 Salir
# Inserte la opcion a realizar: 1
# Inserte el nombre del cardiólogo que desea agregar: Sami
# 1 Agregar elemento a la lista
# 2 Modificar elemento de la lista
# 3 Borrar elemento de la lista
# 4 Mostrar elementos de la lista
# 5 Salir
# Inserte la opcion a realizar: 1
# Inserte el nombre del cardiólogo que desea agregar: Hugo
# 1 Agregar elemento a la lista
# ...
